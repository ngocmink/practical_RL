# %% [markdown]
# <a href="https://colab.research.google.com/github/ngocmink/practical_RL/blob/main/week06_policy_based/a2c-optional.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys, os
if 'google.colab' in sys.modules and not os.path.exists('.setup_complete'):
    # Install xvfb and our launcher script for it
    # !apt-get install -y xvfb
    # !wget -q https://raw.githubusercontent.com/yandexdataschool/Practical_RL/master/xvfb -O ../xvfb

    # Download dependencies from Github
    # !wget https://raw.githubusercontent.com/yandexdataschool/Practical_RL/master/week06_policy_based/atari_wrappers.py
    # !wget https://raw.githubusercontent.com/yandexdataschool/Practical_RL/master/week06_policy_based/env_batch.py
    # !wget https://raw.githubusercontent.com/yandexdataschool/Practical_RL/master/week06_policy_based/runners.py

    # Update the gym environment to be compatible with the Atari environment
    # !pip install -q gymnasium[atari,accept-rom-license]
    # !pip install -q tensorboardX

    # !touch .setup_complete

# This code creates a virtual display to draw game images on.
# It will have no effect if your machine has a monitor.
if type(os.environ.get("DISPLAY")) is not str or len(os.environ.get("DISPLAY")) == 0:
    # !bash ../xvfb start
    os.environ['DISPLAY'] = ':1'

# %% [markdown]
# # Implementing Advantage-Actor Critic (A2C)

# %% [markdown]
# In this notebook you will implement Advantage Actor Critic algorithm that trains on a batch of Atari 2600 environments running in parallel.
#
# Firstly, we will use environment wrappers implemented in file `atari_wrappers.py`. These wrappers preprocess observations (resize, grayscale, take max between frames, skip frames and stack them together) and rewards. Some of the wrappers help to reset the environment and pass `done` flag equal to `True` when agent dies.
# File `env_batch.py` includes implementation of `ParallelEnvBatch` class that allows to run multiple environments in parallel. To create an environment we can use `nature_dqn_env` function. Note that if you are using
# PyTorch and not using `tensorboardX` you will need to implement a wrapper that will log **raw** total rewards that the *unwrapped* environment returns and redefine the implemention of `nature_dqn_env` function here.

# %%
# !pip install "gymnasium[atari]" "autorom" "ale-py" tensorboardX --upgrade
# !AutoROM --accept-license
# Out:
# Requirement already satisfied: autorom in /usr/local/lib/python3.12/dist-packages (0.6.1)
# Requirement already satisfied: ale-py in /usr/local/lib/python3.12/dist-packages (0.11.2)
# Requirement already satisfied: tensorboardX in /usr/local/lib/python3.12/dist-packages (2.6.4)
# Requirement already satisfied: gymnasium[atari] in /usr/local/lib/python3.12/dist-packages (1.2.2)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[atari]) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[atari]) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[atari]) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium[atari]) (0.0.4)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from autorom) (8.3.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from autorom) (2.32.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tensorboardX) (25.0)
# Requirement already satisfied: protobuf>=3.20 in /usr/local/lib/python3.12/dist-packages (from tensorboardX) (5.29.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->autorom) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->autorom) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->autorom) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->autorom) (2025.11.12)
# AutoROM will download the Atari 2600 ROMs.
# They will be installed to:
# 	/usr/local/lib/python3.12/dist-packages/AutoROM/roms
#
# Existing ROMs will be overwritten.

# %%
import numpy as np
import gymnasium as gym
from atari_wrappers import nature_dqn_env


env_name = "SpaceInvadersNoFrameskip-v4"
nenvs = 8  # change this if you have more than 8 CPU ;)
summaries = "Tensorboard"

env = nature_dqn_env(env_name, nenvs=nenvs, summaries=summaries)
obs, _ = env.reset()
n_actions = env.action_space.n
print(n_actions)
assert obs.shape == (nenvs, 4, 84, 84)
assert obs.dtype == np.float32
# Out:
# 6

# %% [markdown]
# Next, we will need to implement a model that predicts logits and values. It is suggested that you use the same model as in [Nature DQN paper](https://www.nature.com/articles/nature14236) with a modification that instead of having a single output layer, it will have two output layers taking as input the output of the last hidden layer. **Note** that this model is different from the model you used in homework where you implemented DQN. You can use your favorite deep learning framework here. We suggest that you use orthogonal initialization with parameter $\sqrt{2}$ for kernels and initialize biases with zeros.

# %%
# import tensorflow as torch
# import torch as tf

import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np

class Model_A2C(nn.Module):
  def __init__(self, n_actions):
    super(Model_A2C, self).__init__()
    self.model = nn.Sequential(
      nn.Conv2d(4, 32, kernel_size=8, stride=4),
      nn.ReLU(),
      nn.Conv2d(32, 64, kernel_size=3, stride=2),
      nn.ReLU(),
      nn.Conv2d(64, 96, kernel_size=3, stride=2),
      nn.ReLU(),
      nn.Conv2d(96, 96, kernel_size=3, stride=2),
      nn.ReLU(),
      nn.Flatten(),
    )

    self.fc_action = nn.Linear(96, n_actions)
    self.fc_value = nn.Linear(96, 1)

  def forward(self, x):
    actions = self.fc_action(self.model(x))
    value = self.fc_value(self.model(x))
    return actions, value

# %%
model = Model_A2C(n_actions)
x = torch.randn(8, 4, 84, 84)
a, v = model(x)
print(a.shape, v.shape)
# Out:
# torch.Size([8, 6]) torch.Size([8, 1])

# %% [markdown]
# You will also need to define and use a policy that wraps the model. While the model computes logits for all actions, the policy will sample actions and also compute their log probabilities.  `policy.act` should return a dictionary of all the arrays that are needed to interact with an environment and train the model.
#  Note that actions must be an `np.ndarray` while the other
# tensors need to have the type determined by your deep learning framework.

# %%
class Policy:
    def __init__(self, model):
        self.model = model

    def act(self, inputs):
        # Implement a policy by calling the model, sampling actions and computing their log probs.
        # Should return a dict containing keys ['actions', 'logits', 'log_probs', 'values'].

        logits, values = self.model(inputs)
        # probs = torch.exp(logits) / torch.sum(torch.exp(logits))
        probs = F.softmax(logits, -1)
        probs = probs.detach().cpu().numpy()
        actions = np.array([np.random.choice(len(probs[0]), p=p) for p in probs])
        # print(actions)
        log_probs = torch.log(torch.tensor(probs[np.arange(len(actions)), actions], dtype=torch.float32))
        actions = torch.tensor(actions, dtype=torch.float32)
        return {'actions': actions,
                'logits': logits,
                'log_probs': log_probs,
                'values': values
               }

# %%
policy = Policy(model)
obs, _ = env.reset()
obs_t = torch.tensor(obs, dtype=torch.float32).cpu()
actions = policy.act(obs_t)['actions'].detach().cpu().numpy().astype(int)
print(policy.act(obs_t)['log_probs'].shape)
# print(obs_t[0])
# print(obs_t[1])
s, r, _, _, _ = env.step(actions)
# print(s[0])
actions = policy.act(torch.tensor(s, dtype=torch.float32))['actions'].detach().cpu().numpy().astype(int)
s, r, _, _, _ = env.step(actions)
# print(s[0])
# Out:
# torch.Size([8])

# %% [markdown]
# Next will pass the environment and policy to a runner that collects partial trajectories from the environment.
# The class that does is is already implemented for you.

# %%
from runners import EnvRunner

# %% [markdown]
# This runner interacts with the environment for a given number of steps and returns a dictionary containing
# keys
#
# * 'observations'
# * 'rewards'
# * 'resets'
# * 'actions'
# * all other keys that you defined in `Policy`
#
# under each of these keys there is a python `list` of interactions with the environment. This list has length $T$ that is size of partial trajectory. Partial trajectory for given moment `t` is part of `ComputeValueTargets.__call__` input argument `trajectory` from moment `t` to the end (i.e. it's different at each iteration in the algorithm).

# %% [markdown]
# To train the part of the model that predicts state values you will need to compute the value targets.
# Any callable could be passed to `EnvRunner` to be applied to each partial trajectory after it is collected.
# Thus, we can implement and use `ComputeValueTargets` callable.
# The formula for the value targets is simple:
#
# $$
# \hat v(s_t) = \left( \sum_{t'=0}^{T - 1} \gamma^{t'}r_{t+t'} \right) + \gamma^T \hat{v}(s_{t+T}),
# $$
#
# In implementation, however, do not forget to use
# `trajectory['resets']` flags to check if you need to add the value targets at the next step when
# computing value targets for the current step. You can access `trajectory['state']['latest_observation']`
# to get last observations in partial trajectory &mdash; $s_{t+T}$.

# %%
class ComputeValueTargets:
    def __init__(self, policy, T, N, gamma=0.99):
        self.policy = policy
        self.gamma = gamma
        self.T = T
        self.N = N

    def __call__(self, trajectory):
        """Compute value targets for a given partial trajectory."""

        # This method should modify trajectory inplace by adding
        # an item with key 'value_targets' to it.

        value = 0
        value_targets = [0] * (self.N * self.T)
        rewards = trajectory['rewards']
        resets = trajectory['resets']

        # print(trajectory['obs'][-1].shape)
        for n in range(self.N):
          for t in reversed(range(self.T)):
            # print(trajectory['obs'][i].shape)
            if resets[t * self.T + n] == 1:
              value = rewards[t * self.T + n] + self.gamma * self.policy.act(trajectory['obs'][t * self.T + n])['values']
              value_targets.insert(0, value)
            else:
              value = rewards[t * self.T + n] + self.gamma * value
              value_targets.insert(0, value)

        trajectory['value_targets'] = torch.tensor(value_targets)

# %% [markdown]
# After computing value targets we will transform lists of interactions into tensors
# with the first dimension `batch_size` which is equal to `env_steps * num_envs`, i.e. you essentially need
# to flatten the first two dimensions.

# %%
class MergeTimeBatch:
    def __call__(self, trajectory):
        new_traj = {}
        for k, v in trajectory.items():
            v = [torch.as_tensor(x, dtype=torch.float32) for x in v]
            v = torch.stack(v)
            new_traj[k] = v.reshape(-1, *v.shape[2:])
        return new_traj

# %%
model = Model_A2C(n_actions)
policy = Policy(model)
runner = EnvRunner(
    env=env,
    policy=policy,
    nsteps=5,
    transforms=[
        ComputeValueTargets(policy, T=36, N=8),
        MergeTimeBatch(),
    ],
)

# %% [markdown]
# Now is the time to implement the advantage actor critic algorithm itself. You can look into your lecture,
# [Mnih et al. 2016](https://arxiv.org/abs/1602.01783) paper, and [lecture](https://www.youtube.com/watch?v=Tol_jw5hWnI&list=PLkFD6_40KJIxJMR-j5A1mkxK26gh_qg37&index=20) by Sergey Levine.

# %%
class A2C:
    def __init__(self,
                 policy,
                 optimizer,
                 T,
                 N,
                 value_loss_coef=0.25,
                 entropy_coef=0.01,
                 max_grad_norm=0.5):
        self.policy = policy
        self.optimizer = optimizer
        self.value_loss_coef = value_loss_coef
        self.entropy_coef = entropy_coef
        self.max_grad_norm = max_grad_norm
        self.T = T
        self.N = N

    def policy_loss(self, trajectory):
        # You will need to compute advantages here.
        traj = ComputeValueTargets(self.policy, self.T, self.N)
        traj(trajectory)
        entropy = (trajectory['log_probs'] * torch.exp(trajectory['log_probs'])).mean()
        # print(trajectory['log_probs'].shape)
        # print(trajectory['value_targets'].shape)
        loss = -torch.mean(trajectory['log_probs'] * trajectory['value_targets'] - trajectory['values']) - self.entropy_coef * entropy
        # print(loss)
        return loss

    def value_loss(self, trajectory):
        loss = self.value_loss_coef * torch.mean((trajectory['value_targets'] - trajectory['values']) ** 2)
        # print(loss)
        return loss

    def loss(self, trajectory):
        loss = self.policy_loss(trajectory) + self.value_loss(trajectory)
        return loss

    def step(self, trajectory):
        loss = self.loss(trajectory)
        self.optimizer.zero_grad()
        loss.backward()
        nn.utils.clip_grad_norm_(self.policy.model.parameters(), self.max_grad_norm)
        self.optimizer.step()

# %% [markdown]
# Now you can train your model. With reasonable hyperparameters training on a single GTX1080 for 10 million steps across all batched environments (which translates to about 5 hours of wall clock time)
# it should be possible to achieve *average raw reward over last 100 episodes* (the average is taken over 100 last
# episodes in each environment in the batch) of about 600. You should plot this quantity with respect to
# `runner.step_var` &mdash; the number of interactions with all environments. It is highly
# encouraged to also provide plots of the following quantities (these are useful for debugging as well):
#
# * [Coefficient of Determination](https://en.wikipedia.org/wiki/Coefficient_of_determination) between
# value targets and value predictions
# * Entropy of the policy $\pi$
# * Value loss
# * Policy loss
# * Value targets
# * Value predictions
# * Gradient norm
# * Advantages
# * A2C loss
#
# For optimization we suggest you use RMSProp with learning rate starting from 7e-4 and linearly decayed to 0, smoothing constant (alpha in PyTorch and decay in TensorFlow) equal to 0.99 and epsilon equal to 1e-5.

# %%
# #if you use TensorboardSummaries
# %load_ext tensorboard
# %tensorboard --logdir logs

# %%
import torch.optim as optim

merge = MergeTimeBatch()
n_actions = env.action_space.n
model = Model_A2C(n_actions)
policy = Policy(model)
optimizer = optim.Adam(model.parameters(), lr=1e-4)
a2c = A2C(policy, optimizer, 36, nenvs)

n_episodes = 2000
for ep in range(n_episodes):
    obs, _ = env.reset()
    done = False

    # Trajectory lưu tensor
    trajectory = {
        'obs': [],
        'actions': [],
        'log_probs': [],
        'rewards': [],
        'values': [],
        'resets': []
    }
    # print("Trajectory type:", type(trajectory))
    # print(trajectory)
    total_reward = 0

    for _ in range(36):
        # ----------------------------
        # Preprocess obs: convert to 4D tensor [1, C, H, W] for Conv2d
        # ----------------------------
        # print(obs.shape)
        obs_t = torch.tensor(obs, dtype=torch.float32)


        act_out = policy.act(obs_t)
        actions = act_out['actions']
        if isinstance(actions, torch.Tensor):
          actions = actions.cpu().numpy().astype(int)

        # Step environment
        next_obs, rewards, terminated, truncated, _ = env.step(actions)
        dones = np.logical_or(terminated, truncated)

        # ----------------------------
        # Store trajectory tensors
        # ----------------------------
        trajectory['obs'].append(obs_t)
        trajectory['actions'].append(act_out['actions'])
        trajectory['log_probs'].append(act_out['log_probs'])
        trajectory['values'].append(act_out['values'])
        trajectory['rewards'].append(torch.tensor(rewards, dtype=torch.float32))
        trajectory['resets'].append(torch.tensor(dones, dtype=torch.float32))

        total_reward = np.mean(rewards)
        obs = next_obs
        done = np.any(dones)
        if done:
          next_obs, _ = env.reset()


    trajectory = merge(trajectory)
    # print(trajectory['obs'].shape)
    # print(trajectory['rewards'].shape)


    # ----------------------------
    # Update A2C
    # ----------------------------
    loss = a2c.loss(trajectory)
    actor_l = a2c.policy_loss(trajectory)
    critic_l = a2c.value_loss(trajectory)
    a2c.step(trajectory)

    if ep % 10 == 0:
        print(f"Ep {ep} | Total Reward: {total_reward:.1f} | Loss: {loss:.4f} | Actor: {actor_l:.4f} | Critic: {critic_l:.4f}")
# Out:
# Ep 0 | Total Reward: 0.0 | Loss: 0.2628 | Actor: 0.2194 | Critic: 0.0433
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-351975629.py in <cell line: 0>()
#      68     # Update A2C
#      69     # ----------------------------
# ---> 70     loss = a2c.loss(trajectory)
#      71     actor_l = a2c.policy_loss(trajectory)
#      72     critic_l = a2c.value_loss(trajectory)
#
# /tmp/ipython-input-20180398.py in loss(self, trajectory)
#      33
#      34     def loss(self, trajectory):
# ---> 35         loss = self.policy_loss(trajectory) + self.value_loss(trajectory)
#      36         return loss
#      37
#
# /tmp/ipython-input-20180398.py in policy_loss(self, trajectory)
#      19         # You will need to compute advantages here.
#      20         traj = ComputeValueTargets(self.policy, self.T, self.N)
# ---> 21         traj(trajectory)
#      22         entropy = (trajectory['log_probs'] * torch.exp(trajectory['log_probs'])).mean()
#      23         # print(trajectory['log_probs'].shape)
#
# /tmp/ipython-input-960263862.py in __call__(self, trajectory)
#      23             idx = n * self.T + t
#      24             if resets[idx] == 1:
# ---> 25                 value = rewards[idx] + self.gamma * self.policy.act(obs[idx])['values']
#      26             else:
#      27                 value = rewards[idx] + self.gamma * value
#
# IndexError: index 117 is out of bounds for axis 0 with size 8

# %% [markdown]
# ### Target networks?
#
# You may recall a technique called "target networks" we used a few weeks ago when we trained a DQN agent to play Atari Breakout and wonder why we have not suggested using them here. The answer is that this is more historical than practical.
#
# While the "chasing the target" problem is still present in actor-critic value estimation and target networks do show up in follow-up papers, the original A3C/A2C papers do not mention them and do not explain this omission.
#
# The hypothesis why this may not be a big deal (compared to Q-learning) goes like this. An A3C/A2C agent selects actions based on policy, not an epsilon greedy exploration function, for which the argmax can change drastically due to tiny errors in function approximation. Therefore, errors in the value target caused by target chasing will cause less damage.
#
# Also, the actor-critic gradient relies on the advantage function $A(s_t, a_t) = Q(s_t, a_t) - V(s_t)$. Compare this to the $Q$-function $Q(s_t, a_t) = r(s_t, a_t) + \gamma \cdot \mathbb{E}_{s_{t+1} \mid s_t, a_t} V(s_{t+1})$ used in Q-learning and SARSA: we would expect that any bias in $V$-function approximation will be carried over from $V(s_{t+1})$ to $V(s_t)$ by gradient updates. However, in the formula for the advantage function the two approximations ($Q$-function and $V$-function) come with opposite signs, and thus the errors will cancel out.
#
# The last reason may be computational. Authors were concerned to beat existent algorithms in the wall-clock learning time, and any overhead of parameter copying (target network update) counted against this goal.
